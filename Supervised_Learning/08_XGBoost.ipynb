# %% [markdown]
# <a href="https://colab.research.google.com/github/seonae0223/machine_learning/blob/main/08_XGBoost.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install xgboost==1.5.0
# Out:
# Collecting xgboost==1.5.0
#   Downloading xgboost-1.5.0-py3-none-manylinux2014_x86_64.whl.metadata (1.7 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from xgboost==1.5.0) (1.25.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from xgboost==1.5.0) (1.11.4)
# Downloading xgboost-1.5.0-py3-none-manylinux2014_x86_64.whl (173.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 173.5/173.5 MB 6.5 MB/s eta 0:00:00
# Installing collected packages: xgboost
#   Attempting uninstall: xgboost
#     Found existing installation: xgboost 2.0.3
#     Uninstalling xgboost-2.0.3:
#       Successfully uninstalled xgboost-2.0.3
# Successfully installed xgboost-1.5.0

# %%
import xgboost as xgb

print(xgb.__version__)
# Out:
# /usr/local/lib/python3.10/dist-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# 1.5.0

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.datasets import load_breast_cancer
import pandas as pd

cancer = load_breast_cancer()

data_df = pd.DataFrame(cancer.data, columns=cancer.feature_names)
data_df['target'] = cancer.target
data_df.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# 0                 0.07871  ...          17.33           184.60      2019.0
# 1                 0.05667  ...          23.41           158.80      1956.0
# 2                 0.05999  ...          25.53           152.50      1709.0
# 3                 0.09744  ...          26.50            98.87       567.7
# 4                 0.05883  ...          16.67           152.20      1575.0
#
#    worst smoothness  worst compactness  worst concavity  worst concave points  \
# 0            0.1622             0.6656           0.7119                0.2654
# 1            0.1238             0.1866           0.2416                0.1860
# 2            0.1444             0.4245           0.4504                0.2430
# 3            0.2098             0.8663           0.6869                0.2575
# 4            0.1374             0.2050           0.4000                0.1625
#
#    worst symmetry  worst fractal dimension  target
# 0          0.4601                  0.11890       0
# 1          0.2750                  0.08902       0
# 2          0.3613                  0.08758       0
# 3          0.6638                  0.17300       0
# 4          0.2364                  0.07678       0
#
# [5 rows x 31 columns]

# %%
from sklearn.model_selection import train_test_split

X_train , X_test , y_train , y_test = train_test_split(
    data_df.drop("target", axis=1),
    data_df['target'],
    random_state=42
)

X_train, X_valid, y_train, y_valid = train_test_split(
    X_train, # X_train 데이터 세트를 기준으로 한번 더 데이터를 자름
    y_train,
    random_state=42
)

# %% [markdown]
# # DMatrix 변환
# - 넘파이 배열, 판다스 데이터 프레임을 DMatrix로 변환

# %%
# !pip install pandas==1.5

# %%
dtr = xgb.DMatrix(data=X_train, label=y_train)
dval = xgb.DMatrix(data=X_valid, label=y_valid)
dtest = xgb.DMatrix(data=X_test, label=y_test)

# %% [markdown]
# #XGB 하이퍼 파라미터 설정

# %%
params = {
    "max_depth": 3,
    'eat': 0.05,
    'objective':'binary:logistic',
    'eval_metric': 'logloss', # 0과 1 사이의 loss일 때, 조금 더 강조된 loss를 확인할 수 있음

}

#최대 400회 훈련 -> 조기 중단 기능(Early Stopping)을 사용할 것이기 때문에 400번을 다 훈련할 필요X
num_rounds = 400

# %% [markdown]
# ## 훈련

# %%
# 평가, 훈련 세트를 함께 넣는 리스트
eval_list = [
    (dtr, 'train'), # 훈련하는 데이터
    (dval, 'eval') # 훈련한 것에 대해 평가하는 데이터
]

xgb_model = xgb.train(
    params=params, #앞서 지정한 하이퍼 파라미터
    dtrain=dtr, # 훈련 데이터 세트 따로 지정
    num_boost_round=num_rounds, # 최대 학습 횟수
    early_stopping_rounds=50, # 성능 개선이 50 라운드 이내에 이루어지지 않으면 학습 중단
    evals=eval_list # 평가 리스트 지정

)
# Out:
# [00:46:51] WARNING: ../src/learner.cc:576:
# Parameters: { "eat" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-logloss:0.47223	eval-logloss:0.48805
# [1]	train-logloss:0.34045	eval-logloss:0.37900
# [2]	train-logloss:0.25744	eval-logloss:0.31620
# [3]	train-logloss:0.19984	eval-logloss:0.27947
# [4]	train-logloss:0.15985	eval-logloss:0.24494
# [5]	train-logloss:0.13100	eval-logloss:0.23093
# [6]	train-logloss:0.11008	eval-logloss:0.21262
# [7]	train-logloss:0.09038	eval-logloss:0.20279
# [8]	train-logloss:0.07607	eval-logloss:0.19069
# [9]	train-logloss:0.06517	eval-logloss:0.18585
# [10]	train-logloss:0.05697	eval-logloss:0.17404
# [11]	train-logloss:0.05017	eval-logloss:0.16949
# [12]	train-logloss:0.04466	eval-logloss:0.16308
# [13]	train-logloss:0.04038	eval-logloss:0.16144
# [14]	train-logloss:0.03647	eval-logloss:0.16185
# [15]	train-logloss:0.03297	eval-logloss:0.15507
# [16]	train-logloss:0.02994	eval-logloss:0.15027
# [17]	train-logloss:0.02763	eval-logloss:0.15043
# [18]	train-logloss:0.02584	eval-logloss:0.14485
# [19]	train-logloss:0.02355	eval-logloss:0.14151
# [20]	train-logloss:0.02199	eval-logloss:0.14150
# [21]	train-logloss:0.02075	eval-logloss:0.13900
# [22]	train-logloss:0.01983	eval-logloss:0.14040
# [23]	train-logloss:0.01853	eval-logloss:0.13811
# [24]	train-logloss:0.01753	eval-logloss:0.13858
# [25]	train-logloss:0.01685	eval-logloss:0.14075
# [26]	train-logloss:0.01609	eval-logloss:0.13783
# [27]	train-logloss:0.01565	eval-logloss:0.13645
# [28]	train-logloss:0.01484	eval-logloss:0.13485
# [29]	train-logloss:0.01443	eval-logloss:0.13412
# [30]	train-logloss:0.01391	eval-logloss:0.13183
# [31]	train-logloss:0.01368	eval-logloss:0.12972
# [32]	train-logloss:0.01316	eval-logloss:0.12833
# [33]	train-logloss:0.01284	eval-logloss:0.12843
# [34]	train-logloss:0.01253	eval-logloss:0.12468
# [35]	train-logloss:0.01212	eval-logloss:0.12538
# [36]	train-logloss:0.01180	eval-logloss:0.12410
# [37]	train-logloss:0.01153	eval-logloss:0.12126
# [38]	train-logloss:0.01131	eval-logloss:0.12069
# [39]	train-logloss:0.01100	eval-logloss:0.11837
# [40]	train-logloss:0.01076	eval-logloss:0.11733
# [41]	train-logloss:0.01043	eval-logloss:0.11687
# [42]	train-logloss:0.01030	eval-logloss:0.11515
# [43]	train-logloss:0.01019	eval-logloss:0.11651
# [44]	train-logloss:0.01008	eval-logloss:0.11808
# [45]	train-logloss:0.00996	eval-logloss:0.11646
# [46]	train-logloss:0.00986	eval-logloss:0.11638
# [47]	train-logloss:0.00976	eval-logloss:0.11702
# [48]	train-logloss:0.00967	eval-logloss:0.11554
# [49]	train-logloss:0.00956	eval-logloss:0.11694
# [50]	train-logloss:0.00946	eval-logloss:0.11750
# [51]	train-logloss:0.00937	eval-logloss:0.11620
# [52]	train-logloss:0.00928	eval-logloss:0.11753
# [53]	train-logloss:0.00919	eval-logloss:0.11606
# [54]	train-logloss:0.00911	eval-logloss:0.11645
# [55]	train-logloss:0.00902	eval-logloss:0.11640
# [56]	train-logloss:0.00894	eval-logloss:0.11665
# [57]	train-logloss:0.00886	eval-logloss:0.11716
# [58]	train-logloss:0.00878	eval-logloss:0.11798
# [59]	train-logloss:0.00870	eval-logloss:0.11658
# [60]	train-logloss:0.00863	eval-logloss:0.11540
# [61]	train-logloss:0.00856	eval-logloss:0.11584
# [62]	train-logloss:0.00850	eval-logloss:0.11587
# [63]	train-logloss:0.00843	eval-logloss:0.11611
# [64]	train-logloss:0.00836	eval-logloss:0.11660
# [65]	train-logloss:0.00830	eval-logloss:0.11741
# [66]	train-logloss:0.00824	eval-logloss:0.11676
# [67]	train-logloss:0.00819	eval-logloss:0.11680
# [68]	train-logloss:0.00813	eval-logloss:0.11724
# [69]	train-logloss:0.00808	eval-logloss:0.11617
# [70]	train-logloss:0.00803	eval-logloss:0.11499
# [71]	train-logloss:0.00798	eval-logloss:0.11579
# [72]	train-logloss:0.00793	eval-logloss:0.11482
# [73]	train-logloss:0.00788	eval-logloss:0.11541
# [74]	train-logloss:0.00784	eval-logloss:0.11550
# [75]	train-logloss:0.00779	eval-logloss:0.11537
# [76]	train-logloss:0.00775	eval-logloss:0.11614
# [77]	train-logloss:0.00771	eval-logloss:0.11505
# [78]	train-logloss:0.00766	eval-logloss:0.11419
# [79]	train-logloss:0.00762	eval-logloss:0.11468
# [80]	train-logloss:0.00758	eval-logloss:0.11476
# [81]	train-logloss:0.00754	eval-logloss:0.11394
# [82]	train-logloss:0.00751	eval-logloss:0.11440
# [83]	train-logloss:0.00747	eval-logloss:0.11499
# [84]	train-logloss:0.00744	eval-logloss:0.11392
# [85]	train-logloss:0.00741	eval-logloss:0.11464
# [86]	train-logloss:0.00737	eval-logloss:0.11383
# [87]	train-logloss:0.00734	eval-logloss:0.11314
# [88]	train-logloss:0.00731	eval-logloss:0.11382
# [89]	train-logloss:0.00728	eval-logloss:0.11440
# [90]	train-logloss:0.00726	eval-logloss:0.11429
# [91]	train-logloss:0.00724	eval-logloss:0.11492
# [92]	train-logloss:0.00721	eval-logloss:0.11414
# [93]	train-logloss:0.00719	eval-logloss:0.11458
# [94]	train-logloss:0.00717	eval-logloss:0.11399
# [95]	train-logloss:0.00715	eval-logloss:0.11442
# [96]	train-logloss:0.00713	eval-logloss:0.11503
# [97]	train-logloss:0.00711	eval-logloss:0.11430
# [98]	train-logloss:0.00708	eval-logloss:0.11483
# [99]	train-logloss:0.00707	eval-logloss:0.11541
# [100]	train-logloss:0.00705	eval-logloss:0.11581
# [101]	train-logloss:0.00703	eval-logloss:0.11622
# [102]	train-logloss:0.00701	eval-logloss:0.11563
# [103]	train-logloss:0.00699	eval-logloss:0.11611
# [104]	train-logloss:0.00698	eval-logloss:0.11647
# [105]	train-logloss:0.00696	eval-logloss:0.11585
# [106]	train-logloss:0.00695	eval-logloss:0.11653
# [107]	train-logloss:0.00694	eval-logloss:0.11677
# [108]	train-logloss:0.00692	eval-logloss:0.11614
# [109]	train-logloss:0.00691	eval-logloss:0.11647
# [110]	train-logloss:0.00690	eval-logloss:0.11707
# [111]	train-logloss:0.00688	eval-logloss:0.11643
# [112]	train-logloss:0.00687	eval-logloss:0.11666
# [113]	train-logloss:0.00686	eval-logloss:0.11605
# [114]	train-logloss:0.00685	eval-logloss:0.11627
# [115]	train-logloss:0.00684	eval-logloss:0.11580
# [116]	train-logloss:0.00683	eval-logloss:0.11610
# [117]	train-logloss:0.00682	eval-logloss:0.11572
# [118]	train-logloss:0.00681	eval-logloss:0.11594
# [119]	train-logloss:0.00679	eval-logloss:0.11532
# [120]	train-logloss:0.00678	eval-logloss:0.11587
# [121]	train-logloss:0.00677	eval-logloss:0.11532
# [122]	train-logloss:0.00677	eval-logloss:0.11560
# [123]	train-logloss:0.00676	eval-logloss:0.11526
# [124]	train-logloss:0.00675	eval-logloss:0.11497
# [125]	train-logloss:0.00674	eval-logloss:0.11449
# [126]	train-logloss:0.00674	eval-logloss:0.11460
# [127]	train-logloss:0.00674	eval-logloss:0.11460
# [128]	train-logloss:0.00674	eval-logloss:0.11460
# [129]	train-logloss:0.00674	eval-logloss:0.11460
# [130]	train-logloss:0.00674	eval-logloss:0.11460
# [131]	train-logloss:0.00674	eval-logloss:0.11460
# [132]	train-logloss:0.00674	eval-logloss:0.11460
# [133]	train-logloss:0.00674	eval-logloss:0.11460
# [134]	train-logloss:0.00674	eval-logloss:0.11461
# [135]	train-logloss:0.00674	eval-logloss:0.11461
# [136]	train-logloss:0.00674	eval-logloss:0.11461
